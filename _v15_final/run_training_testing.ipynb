# %%
# %run train_v15.py

# %%
# %run test_v15.py
# Out:
# ...
# HSI DENOISING MODEL TESTING - ICVL Protocol
# Test crops: 512×512×31 with training-matched normalization
# ...
# Using device: cpu
#
# Loading trained model...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Desktop/499/hsi/hybArch/test_exp/_v15_final/test_v15.py:302
#     299     return results, summary_stats, model_info
#     301 if __name__ == '__main__':
# --> 302     main()
#
# File ~/Desktop/499/hsi/hybArch/test_exp/_v15_final/test_v15.py:73, in main()
#      71     config = checkpoint.get('config', config)
#      72 else:
# ---> 73     raise FileNotFoundError(f"No model found in {MODEL_PATH}")
#      75 # Initialize model
#      76 model = MemoryOptimizedUNet(
#      77     in_channels=1,
#      78     base_dim=config['base_dim'],
#      79     window_sizes=[4, 8, 16],
#      80     num_bands=config['target_bands']
#      81 ).to(device)
#
# ...
