# %%
# %run utils.py    # .py file name
# Out:
# Loaded HSI key: temp, shape: (200, 200, 191)

# %%
# %run generate_patches_restormer.py
# Out:
# Processing file....: train_Wash3.mat
# Extracted 30 patches from train_Wash3.mat
#
# Processing file....: train_Wash2.mat
# Extracted 30 patches from train_Wash2.mat
#
# Total patches extracted from all files: 60
# Patch visualization saved at: /Users/muhtasimishmumkhan/Desktop/499/hsi/hybArch/HSI_denoising/init/patch_img_MK/train_Wash3.mat_patch_0_2.png

# %%
# %run model_restormer.py
# Out:
# Processing file....: train_Wash3.mat
# Extracted 30 patches from train_Wash3.mat
# Saved 30 patches from train_Wash3.mat to /Users/muhtasimishmumkhan/Desktop/499/hsi/hybArch/HSI_denoising/saved_patches/train_Wash3_patches.mat
#
# Processing file....: train_Wash2.mat
# Extracted 30 patches from train_Wash2.mat
# Saved 30 patches from train_Wash2.mat to /Users/muhtasimishmumkhan/Desktop/499/hsi/hybArch/HSI_denoising/saved_patches/train_Wash2_patches.mat
#
# Total patches extracted from all files: 60
# All patches saved to: /Users/muhtasimishmumkhan/Desktop/499/hsi/hybArch/HSI_denoising/saved_patches
# Patch visualization saved at: /Users/muhtasimishmumkhan/Desktop/499/hsi/hybArch/HSI_denoising/init/patch_img_MK/train_Wash3.mat_patch_0_13.png

# %%
# %run utils.py
# Out:
# Loaded 30 patches from train_Wash2.mat
# Patch shape: torch.Size([191, 32, 32]) (channels, height, width)

# %%
# %run Conv3d_patch.py
# Out:
# ...
# HSI Conv3D Feature Extraction Training
# ...
#
# 1. Loading patches from .mat file...
# Loading patches from: /Users/muhtasimishmumkhan/Desktop/499/hsi/hybArch/HSI_denoising/saved_patches/train_Wash2_patches
# Original patches shape: (30, 191, 32, 32)
# Converted tensor shape: torch.Size([30, 1, 191, 32, 32])
# Successfully loaded 30 patches
# Patch dimensions: torch.Size([1, 191, 32, 32])
#
# 2. Starting training...
# Initial RAM usage: 0.27 GB
# Training on device: mps
# Starting training for 30 epochs...
# Dataset size: 30 patches
# Batch size: 16
# Epoch 1/30 - Loss: 0.1444 - RAM: 0.15 GB
# Epoch 2/30 - Loss: 0.1137 - RAM: 0.08 GB
# Epoch 3/30 - Loss: 0.1021 - RAM: 0.08 GB
# Epoch 4/30 - Loss: 0.0924 - RAM: 0.08 GB
# Epoch 5/30 - Loss: 0.0746 - RAM: 0.06 GB
# Epoch 6/30 - Loss: 0.0719 - RAM: 0.08 GB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...
